# %% [markdown]
# <a href="https://colab.research.google.com/github/aryantyagi0/Train_Video_Processing/blob/main/Copy_of_Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q moviepy



import os, shutil, glob, math, cv2, numpy as np
from moviepy.video.io.VideoFileClip import VideoFileClip
from tqdm import tqdm

# %%
VIDEO_PATH = "/content/DHN_side_view1.mp4"
OUTPUT_ROOT = "Processed_Video"
TRAIN_PREFIX = "DHN_wagon"
SAMPLE_SEC = 0.5
MERGE_SEC = 1.0
MIN_SEG_SEC = 0.6
SAMPLE_FRAME_EVERY = 2
EDGE_OPEN_THRESHOLD = 0.03

# %%
# Cell 3 — thumbnails + histogram-difference candidate generation
os.makedirs(OUTPUT_ROOT, exist_ok=True)
clip = VideoFileClip(VIDEO_PATH)
fps = clip.fps
duration = clip.duration
print(f"Video duration: {duration:.2f}s, fps: {fps}")

sample_times = np.arange(0, duration, SAMPLE_SEC)
thumbs_dir = os.path.join(OUTPUT_ROOT, "thumbs_for_splits")
shutil.rmtree(thumbs_dir, ignore_errors=True)
os.makedirs(thumbs_dir, exist_ok=True)

print("Saving thumbnails...")
sampled_frames = []
for i,t in enumerate(tqdm(sample_times)):
    frame = clip.get_frame(t)
    frame_bgr = cv2.cvtColor((frame*255).astype(np.uint8), cv2.COLOR_RGB2BGR)
    p = os.path.join(thumbs_dir, f"thumb_{i:04d}_{t:.2f}.jpg")
    cv2.imwrite(p, frame_bgr)
    sampled_frames.append((t,p))

# compute HSV hist per thumbnail and Bhattacharyya distance between consecutive thumbnails
def hist_hsv(img_path):
    img = cv2.imread(img_path)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h = cv2.calcHist([hsv], [0,1], None, [50,60], [0,180,0,256])
    cv2.normalize(h, h)
    return h.flatten()

hists = [hist_hsv(p) for _,p in sampled_frames]
dists = [cv2.compareHist(np.float32(hists[i]), np.float32(hists[i+1]), cv2.HISTCMP_BHATTACHARYYA)
         for i in range(len(hists)-1)]
d = np.array(dists)
mean,std = d.mean(), d.std()
threshold = mean + 1.0*std
candidates = [sample_times[i+1] for i in range(len(d)) if d[i] > threshold]


merged = []
for t in candidates:
    if not merged:
        merged.append(t)
    else:
        if t - merged[-1] < MERGE_SEC:
            merged[-1] = (merged[-1] + t)/2.0
        else:
            merged.append(t)
candidates = merged

print("Auto split candidates (seconds):")
print(candidates)
print("\n--> Thumbnails saved to:", thumbs_dir)
print("Inspect thumbnails (Files panel -> open 'thumbs_for_splits') and verify candidates.")
# Out:
# Video duration: 166.68s, fps: 24.25
# Saving thumbnails...
# 100%|██████████| 334/334 [00:11<00:00, 28.69it/s]
# Auto split candidates (seconds):
# [np.float64(29.75), np.float64(40.0), np.float64(46.0), np.float64(50.0), np.float64(52.5), np.float64(62.75), np.float64(72.0), np.float64(78.0), np.float64(88.0), np.float64(89.5), np.float64(91.0), np.float64(103.5), np.float64(106.5), np.float64(108.0), np.float64(115.75), np.float64(117.0), np.float64(120.0), np.float64(121.0), np.float64(145.0), np.float64(148.75), np.float64(154.0), np.float64(159.0), np.float64(160.0), np.float64(161.0), np.float64(162.0), np.float64(163.5)]
#
# --> Thumbnails saved to: Processed_Video/thumbs_for_splits
# Inspect thumbnails (Files panel -> open 'thumbs_for_splits') and verify candidates.

# %%
split_times = candidates.copy()
segments = []
start = 0.0
for t in split_times:
    segments.append((start,float(t)))
    start = float(t)
segments.append((start, duration))
print("Proposed segments:", len(segments))

valid_segments = []
for idx,(s,e) in enumerate(segments, start=1):
    if e - s < MIN_SEG_SEC:
        continue
    folder = os.path.join(OUTPUT_ROOT, f"{TRAIN_PREFIX}_{len(valid_segments)+1}")
    os.makedirs(folder, exist_ok=True)
    out_path = os.path.join(folder, f"{TRAIN_PREFIX}_{len(valid_segments)+1}.mp4")
    print(f"Saving segment {len(valid_segments)+1}: {s:.2f} -> {e:.2f}")
    clip.subclip(s,e).write_videofile(out_path, codec='libx264', audio=False, verbose=False, logger=None)
    valid_segments.append((s,e,folder,out_path))

print("Saved segments:", len(valid_segments))
print("If counts look wrong: re-run Cell 3 with adjusted thresholds or adjust MERGE_SEC / MIN_SEG_SEC.")
# Out:
# Proposed segments: 27
# Saving segment 1: 0.00 -> 29.75
# Saving segment 2: 29.75 -> 40.00
# Saving segment 3: 40.00 -> 46.00
# Saving segment 4: 46.00 -> 50.00
# Saving segment 5: 50.00 -> 52.50
# Saving segment 6: 52.50 -> 62.75
# Saving segment 7: 62.75 -> 72.00
# Saving segment 8: 72.00 -> 78.00
# Saving segment 9: 78.00 -> 88.00
# Saving segment 10: 88.00 -> 89.50
# Saving segment 11: 89.50 -> 91.00
# Saving segment 12: 91.00 -> 103.50
# Saving segment 13: 103.50 -> 106.50
# Saving segment 14: 106.50 -> 108.00
# Saving segment 15: 108.00 -> 115.75
# Saving segment 16: 115.75 -> 117.00
# Saving segment 17: 117.00 -> 120.00
# Saving segment 18: 120.00 -> 121.00
# Saving segment 19: 121.00 -> 145.00
# Saving segment 20: 145.00 -> 148.75
# Saving segment 21: 148.75 -> 154.00
# Saving segment 22: 154.00 -> 159.00
# Saving segment 23: 159.00 -> 160.00
# Saving segment 24: 160.00 -> 161.00
# Saving segment 25: 161.00 -> 162.00
# Saving segment 26: 162.00 -> 163.50
# Saving segment 27: 163.50 -> 166.68
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/DHN_side_view1.mp4, 971808 bytes wanted but 0 bytes read,at frame 4038/4042, at time 166.52/166.68 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/DHN_side_view1.mp4, 971808 bytes wanted but 0 bytes read,at frame 4039/4042, at time 166.56/166.68 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/DHN_side_view1.mp4, 971808 bytes wanted but 0 bytes read,at frame 4040/4042, at time 166.60/166.68 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/DHN_side_view1.mp4, 971808 bytes wanted but 0 bytes read,at frame 4041/4042, at time 166.64/166.68 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Saved segments: 27
# If counts look wrong: re-run Cell 3 with adjusted thresholds or adjust MERGE_SEC / MIN_SEG_SEC.

# %%
# Cell 5 — sample frames inside each saved coach clip
for seg_idx, (s,e,folder,video_file) in enumerate(valid_segments, start=1):
    cap = cv2.VideoCapture(video_file)
    saved = 0; frame_no = 0
    while True:
        ret, frame = cap.read()
        if not ret: break
        if frame_no % SAMPLE_FRAME_EVERY == 0:
            img_path = os.path.join(folder, f"{TRAIN_PREFIX}_{seg_idx}_{saved+1:03d}.jpg")
            cv2.imwrite(img_path, frame)
            saved += 1
        frame_no += 1
    cap.release()
    print(f"Segment {seg_idx}: saved {saved} frames into {folder}")
# Out:
# Segment 1: saved 361 frames into Processed_Video/DHN_wagon_1
# Segment 2: saved 125 frames into Processed_Video/DHN_wagon_2
# Segment 3: saved 73 frames into Processed_Video/DHN_wagon_3
# Segment 4: saved 49 frames into Processed_Video/DHN_wagon_4
# Segment 5: saved 31 frames into Processed_Video/DHN_wagon_5
# Segment 6: saved 125 frames into Processed_Video/DHN_wagon_6
# Segment 7: saved 113 frames into Processed_Video/DHN_wagon_7
# Segment 8: saved 73 frames into Processed_Video/DHN_wagon_8
# Segment 9: saved 122 frames into Processed_Video/DHN_wagon_9
# Segment 10: saved 19 frames into Processed_Video/DHN_wagon_10
# Segment 11: saved 19 frames into Processed_Video/DHN_wagon_11
# Segment 12: saved 152 frames into Processed_Video/DHN_wagon_12
# Segment 13: saved 37 frames into Processed_Video/DHN_wagon_13
# Segment 14: saved 19 frames into Processed_Video/DHN_wagon_14
# Segment 15: saved 94 frames into Processed_Video/DHN_wagon_15
# Segment 16: saved 16 frames into Processed_Video/DHN_wagon_16
# Segment 17: saved 37 frames into Processed_Video/DHN_wagon_17
# Segment 18: saved 13 frames into Processed_Video/DHN_wagon_18
# Segment 19: saved 291 frames into Processed_Video/DHN_wagon_19
# Segment 20: saved 46 frames into Processed_Video/DHN_wagon_20
# Segment 21: saved 64 frames into Processed_Video/DHN_wagon_21
# Segment 22: saved 61 frames into Processed_Video/DHN_wagon_22
# Segment 23: saved 13 frames into Processed_Video/DHN_wagon_23
# Segment 24: saved 13 frames into Processed_Video/DHN_wagon_24
# Segment 25: saved 13 frames into Processed_Video/DHN_wagon_25
# Segment 26: saved 19 frames into Processed_Video/DHN_wagon_26
# Segment 27: saved 39 frames into Processed_Video/DHN_wagon_27

# %%
for seg_idx, (s,e,folder,video_file) in enumerate(valid_segments, start=1):
    jpgs = sorted(glob.glob(os.path.join(folder, f"{TRAIN_PREFIX}_{seg_idx}_*.jpg")))
    annotated_frames_dir = os.path.join(folder, "annotated_frames")
    shutil.rmtree(annotated_frames_dir, ignore_errors=True)
    os.makedirs(annotated_frames_dir, exist_ok=True)
    segment_boxes = []
    for i, p in enumerate(jpgs):
        img = cv2.imread(p)

        boxes = detect_doors_in_image(img, EDGE_OPEN_THRESHOLD)
        segment_boxes.append((p, boxes))

        annotated_img = img.copy() # Create a copy to draw on
        for (x,y,ww,hh,label, conf) in boxes: # Added conf to unpack
            cv2.rectangle(annotated_img, (x,y), (x+ww, y+hh), (0,255,0), 2)
            cv2.putText(annotated_img, f"{label}: {conf:.2f}", (x, y-8), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2) # Display confidence

        outp = os.path.join(annotated_frames_dir, f"{TRAIN_PREFIX}_{seg_idx}_{i+1:03d}_ann.jpg") # Save annotated image with a distinct name
        cv2.imwrite(outp, annotated_img)

    detected_boxes_per_segment[seg_idx] = segment_boxes # Store detection results per segment
    print(f"Processed and annotated {len(jpgs)} frames for coach {seg_idx} using YOLOv8. Annotated images saved to {annotated_frames_dir}.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 288x640 2 trains, 112.8ms
# Speed: 3.9ms preprocess, 112.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.4ms
# Speed: 5.2ms preprocess, 116.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.0ms
# Speed: 4.0ms preprocess, 111.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.0ms
# Speed: 4.0ms preprocess, 121.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.3ms
# Speed: 3.9ms preprocess, 114.3ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.6ms
# Speed: 5.4ms preprocess, 124.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.4ms
# Speed: 3.8ms preprocess, 121.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.9ms
# Speed: 3.8ms preprocess, 116.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.6ms
# Speed: 3.5ms preprocess, 120.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.2ms
# Speed: 4.0ms preprocess, 121.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.1ms
# Speed: 4.0ms preprocess, 123.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.3ms
# Speed: 3.4ms preprocess, 113.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 147.8ms
# Speed: 4.2ms preprocess, 147.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.8ms
# Speed: 3.8ms preprocess, 112.8ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.2ms
# Speed: 4.9ms preprocess, 117.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 140.4ms
# Speed: 4.2ms preprocess, 140.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.6ms
# Speed: 3.9ms preprocess, 120.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.3ms
# Speed: 3.3ms preprocess, 114.3ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.3ms
# Speed: 4.5ms preprocess, 118.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 139.8ms
# Speed: 6.3ms preprocess, 139.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.5ms
# Speed: 4.9ms preprocess, 120.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.1ms
# Speed: 5.2ms preprocess, 117.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.7ms
# Speed: 4.1ms preprocess, 112.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 108.6ms
# Speed: 3.6ms preprocess, 108.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.8ms
# Speed: 4.0ms preprocess, 115.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.7ms
# Speed: 4.0ms preprocess, 112.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.2ms
# Speed: 3.7ms preprocess, 115.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 130.0ms
# Speed: 4.1ms preprocess, 130.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.4ms
# Speed: 4.4ms preprocess, 116.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.3ms
# Speed: 3.9ms preprocess, 115.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.3ms
# Speed: 3.9ms preprocess, 117.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.5ms
# Speed: 4.3ms preprocess, 115.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.7ms
# Speed: 3.5ms preprocess, 110.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.5ms
# Speed: 4.2ms preprocess, 119.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 137.0ms
# Speed: 4.1ms preprocess, 137.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 107.0ms
# Speed: 3.7ms preprocess, 107.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.2ms
# Speed: 4.4ms preprocess, 116.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.8ms
# Speed: 3.9ms preprocess, 113.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.0ms
# Speed: 3.4ms preprocess, 126.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.1ms
# Speed: 4.0ms preprocess, 118.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.8ms
# Speed: 4.0ms preprocess, 123.8ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.4ms
# Speed: 3.9ms preprocess, 123.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.7ms
# Speed: 4.0ms preprocess, 125.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.4ms
# Speed: 5.3ms preprocess, 113.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 108.1ms
# Speed: 3.1ms preprocess, 108.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.1ms
# Speed: 4.8ms preprocess, 119.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.5ms
# Speed: 4.1ms preprocess, 126.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.4ms
# Speed: 4.6ms preprocess, 116.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.9ms
# Speed: 4.6ms preprocess, 118.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.6ms
# Speed: 4.0ms preprocess, 129.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.9ms
# Speed: 4.2ms preprocess, 112.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.2ms
# Speed: 4.3ms preprocess, 124.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.6ms
# Speed: 3.9ms preprocess, 125.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 1 truck, 115.8ms
# Speed: 3.5ms preprocess, 115.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 1 truck, 120.5ms
# Speed: 4.1ms preprocess, 120.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 1 truck, 116.1ms
# Speed: 4.5ms preprocess, 116.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 1 truck, 108.3ms
# Speed: 3.1ms preprocess, 108.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 1 truck, 127.8ms
# Speed: 5.1ms preprocess, 127.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 1 truck, 119.2ms
# Speed: 3.9ms preprocess, 119.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.3ms
# Speed: 3.6ms preprocess, 112.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.5ms
# Speed: 4.1ms preprocess, 112.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.0ms
# Speed: 4.3ms preprocess, 120.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.9ms
# Speed: 3.9ms preprocess, 110.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.8ms
# Speed: 3.9ms preprocess, 117.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 135.5ms
# Speed: 4.9ms preprocess, 135.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.7ms
# Speed: 3.4ms preprocess, 113.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 107.9ms
# Speed: 3.9ms preprocess, 107.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.8ms
# Speed: 5.0ms preprocess, 115.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.2ms
# Speed: 4.0ms preprocess, 114.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 175.6ms
# Speed: 3.7ms preprocess, 175.6ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 191.3ms
# Speed: 6.9ms preprocess, 191.3ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 192.3ms
# Speed: 4.4ms preprocess, 192.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 178.0ms
# Speed: 4.1ms preprocess, 178.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 169.5ms
# Speed: 4.1ms preprocess, 169.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 167.4ms
# Speed: 3.7ms preprocess, 167.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 172.6ms
# Speed: 4.4ms preprocess, 172.6ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 197.0ms
# Speed: 3.9ms preprocess, 197.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 169.4ms
# Speed: 3.5ms preprocess, 169.4ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.7ms
# Speed: 4.4ms preprocess, 183.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 180.7ms
# Speed: 4.6ms preprocess, 180.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 169.1ms
# Speed: 3.5ms preprocess, 169.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 171.4ms
# Speed: 3.8ms preprocess, 171.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.6ms
# Speed: 6.1ms preprocess, 183.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 184.2ms
# Speed: 12.1ms preprocess, 184.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 172.0ms
# Speed: 3.8ms preprocess, 172.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 174.1ms
# Speed: 3.9ms preprocess, 174.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 226.2ms
# Speed: 3.4ms preprocess, 226.2ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 192.7ms
# Speed: 4.5ms preprocess, 192.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 191.1ms
# Speed: 5.5ms preprocess, 191.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 177.2ms
# Speed: 3.4ms preprocess, 177.2ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 195.3ms
# Speed: 4.1ms preprocess, 195.3ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 159.7ms
# Speed: 5.3ms preprocess, 159.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.3ms
# Speed: 3.7ms preprocess, 116.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 136.9ms
# Speed: 5.4ms preprocess, 136.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.3ms
# Speed: 4.5ms preprocess, 125.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.7ms
# Speed: 3.4ms preprocess, 119.7ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.8ms
# Speed: 4.8ms preprocess, 126.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.9ms
# Speed: 4.3ms preprocess, 121.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 127.2ms
# Speed: 3.8ms preprocess, 127.2ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.1ms
# Speed: 4.0ms preprocess, 123.1ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 134.8ms
# Speed: 3.9ms preprocess, 134.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.0ms
# Speed: 3.4ms preprocess, 121.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.4ms
# Speed: 4.2ms preprocess, 123.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.6ms
# Speed: 4.0ms preprocess, 125.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.1ms
# Speed: 3.3ms preprocess, 119.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.9ms
# Speed: 5.1ms preprocess, 110.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.0ms
# Speed: 4.5ms preprocess, 113.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 135.4ms
# Speed: 3.5ms preprocess, 135.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.8ms
# Speed: 4.0ms preprocess, 125.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.5ms
# Speed: 3.8ms preprocess, 121.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.0ms
# Speed: 3.7ms preprocess, 120.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.3ms
# Speed: 5.6ms preprocess, 124.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.0ms
# Speed: 5.0ms preprocess, 125.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.2ms
# Speed: 4.1ms preprocess, 114.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 137.4ms
# Speed: 4.0ms preprocess, 137.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.9ms
# Speed: 5.6ms preprocess, 126.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.3ms
# Speed: 3.5ms preprocess, 111.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.1ms
# Speed: 4.0ms preprocess, 124.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.6ms
# Speed: 3.9ms preprocess, 118.6ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.5ms
# Speed: 3.6ms preprocess, 112.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.0ms
# Speed: 4.3ms preprocess, 117.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.9ms
# Speed: 4.5ms preprocess, 113.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 136.4ms
# Speed: 3.5ms preprocess, 136.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.3ms
# Speed: 4.0ms preprocess, 113.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.8ms
# Speed: 4.0ms preprocess, 117.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 109.9ms
# Speed: 3.2ms preprocess, 109.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.2ms
# Speed: 4.0ms preprocess, 121.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.2ms
# Speed: 4.0ms preprocess, 126.2ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.8ms
# Speed: 4.7ms preprocess, 114.8ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 141.6ms
# Speed: 4.1ms preprocess, 141.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.9ms
# Speed: 4.2ms preprocess, 117.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 109.0ms
# Speed: 4.5ms preprocess, 109.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.6ms
# Speed: 4.2ms preprocess, 121.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 133.1ms
# Speed: 6.3ms preprocess, 133.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 113.3ms
# Speed: 4.8ms preprocess, 113.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 123.0ms
# Speed: 4.0ms preprocess, 123.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 136.0ms
# Speed: 4.0ms preprocess, 136.0ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 117.9ms
# Speed: 3.6ms preprocess, 117.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 117.7ms
# Speed: 4.1ms preprocess, 117.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 117.5ms
# Speed: 3.8ms preprocess, 117.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 113.1ms
# Speed: 3.9ms preprocess, 113.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 110.4ms
# Speed: 4.0ms preprocess, 110.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 2 trains, 131.2ms
# Speed: 4.7ms preprocess, 131.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.4ms
# Speed: 4.4ms preprocess, 117.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 130.1ms
# Speed: 4.4ms preprocess, 130.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.7ms
# Speed: 4.5ms preprocess, 120.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.3ms
# Speed: 4.1ms preprocess, 119.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.7ms
# Speed: 4.6ms preprocess, 126.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.2ms
# Speed: 4.2ms preprocess, 125.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.0ms
# Speed: 4.0ms preprocess, 115.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 127.4ms
# Speed: 4.3ms preprocess, 127.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 133.4ms
# Speed: 4.8ms preprocess, 133.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.6ms
# Speed: 3.6ms preprocess, 115.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.3ms
# Speed: 4.4ms preprocess, 119.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 127.6ms
# Speed: 4.1ms preprocess, 127.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.0ms
# Speed: 3.5ms preprocess, 115.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.0ms
# Speed: 4.0ms preprocess, 115.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 130.8ms
# Speed: 4.3ms preprocess, 130.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 142.5ms
# Speed: 5.0ms preprocess, 142.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.8ms
# Speed: 4.1ms preprocess, 123.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 127.2ms
# Speed: 4.1ms preprocess, 127.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 154.3ms
# Speed: 3.5ms preprocess, 154.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 180.1ms
# Speed: 3.9ms preprocess, 180.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 187.7ms
# Speed: 6.1ms preprocess, 187.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 182.7ms
# Speed: 4.3ms preprocess, 182.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 174.3ms
# Speed: 4.7ms preprocess, 174.3ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 170.6ms
# Speed: 3.9ms preprocess, 170.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 158.8ms
# Speed: 5.3ms preprocess, 158.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 177.7ms
# Speed: 6.3ms preprocess, 177.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 182.2ms
# Speed: 4.0ms preprocess, 182.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.3ms
# Speed: 3.4ms preprocess, 183.3ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 173.2ms
# Speed: 5.5ms preprocess, 173.2ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 186.6ms
# Speed: 6.1ms preprocess, 186.6ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 163.6ms
# Speed: 5.6ms preprocess, 163.6ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 172.4ms
# Speed: 5.5ms preprocess, 172.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 186.1ms
# Speed: 4.1ms preprocess, 186.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 179.1ms
# Speed: 3.6ms preprocess, 179.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.6ms
# Speed: 5.5ms preprocess, 183.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.0ms
# Speed: 3.9ms preprocess, 183.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 194.3ms
# Speed: 3.5ms preprocess, 194.3ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 214.9ms
# Speed: 8.5ms preprocess, 214.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 164.8ms
# Speed: 4.9ms preprocess, 164.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.0ms
# Speed: 4.1ms preprocess, 116.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 122.4ms
# Speed: 5.1ms preprocess, 122.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.5ms
# Speed: 3.9ms preprocess, 120.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.0ms
# Speed: 3.4ms preprocess, 116.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.0ms
# Speed: 4.3ms preprocess, 126.0ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 144.3ms
# Speed: 6.0ms preprocess, 144.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.1ms
# Speed: 3.7ms preprocess, 121.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 127.1ms
# Speed: 4.8ms preprocess, 127.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.1ms
# Speed: 5.2ms preprocess, 131.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.8ms
# Speed: 7.7ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.1ms
# Speed: 4.6ms preprocess, 118.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.1ms
# Speed: 4.0ms preprocess, 119.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 133.6ms
# Speed: 3.6ms preprocess, 133.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.0ms
# Speed: 4.1ms preprocess, 118.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.4ms
# Speed: 4.9ms preprocess, 121.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.5ms
# Speed: 4.5ms preprocess, 120.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.4ms
# Speed: 4.5ms preprocess, 125.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 122.9ms
# Speed: 4.1ms preprocess, 122.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.5ms
# Speed: 3.6ms preprocess, 116.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 141.2ms
# Speed: 4.2ms preprocess, 141.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.6ms
# Speed: 5.5ms preprocess, 119.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.3ms
# Speed: 3.5ms preprocess, 114.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.5ms
# Speed: 4.5ms preprocess, 131.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.2ms
# Speed: 3.8ms preprocess, 121.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 106.8ms
# Speed: 3.2ms preprocess, 106.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 122.0ms
# Speed: 4.2ms preprocess, 122.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 138.4ms
# Speed: 5.0ms preprocess, 138.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 139.9ms
# Speed: 3.7ms preprocess, 139.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 132.4ms
# Speed: 5.1ms preprocess, 132.4ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 134.4ms
# Speed: 4.3ms preprocess, 134.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 122.3ms
# Speed: 3.7ms preprocess, 122.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.3ms
# Speed: 4.4ms preprocess, 123.3ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 128.6ms
# Speed: 6.4ms preprocess, 128.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 133.1ms
# Speed: 3.5ms preprocess, 133.1ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 141.9ms
# Speed: 4.0ms preprocess, 141.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.6ms
# Speed: 4.3ms preprocess, 123.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 133.1ms
# Speed: 4.0ms preprocess, 133.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.1ms
# Speed: 4.0ms preprocess, 117.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.7ms
# Speed: 3.3ms preprocess, 119.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.9ms
# Speed: 3.5ms preprocess, 117.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.1ms
# Speed: 3.9ms preprocess, 129.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 146.9ms
# Speed: 4.0ms preprocess, 146.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.3ms
# Speed: 5.0ms preprocess, 119.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.2ms
# Speed: 4.2ms preprocess, 116.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.0ms
# Speed: 3.8ms preprocess, 120.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.0ms
# Speed: 3.6ms preprocess, 117.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.5ms
# Speed: 4.3ms preprocess, 117.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.1ms
# Speed: 4.5ms preprocess, 129.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.6ms
# Speed: 3.4ms preprocess, 126.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 141.2ms
# Speed: 4.7ms preprocess, 141.2ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.0ms
# Speed: 4.1ms preprocess, 119.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.8ms
# Speed: 3.5ms preprocess, 110.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.9ms
# Speed: 3.6ms preprocess, 114.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.4ms
# Speed: 4.1ms preprocess, 114.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 122.7ms
# Speed: 3.5ms preprocess, 122.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 135.3ms
# Speed: 3.9ms preprocess, 135.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.2ms
# Speed: 4.6ms preprocess, 120.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.0ms
# Speed: 4.3ms preprocess, 119.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.8ms
# Speed: 4.4ms preprocess, 114.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.4ms
# Speed: 4.0ms preprocess, 119.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.3ms
# Speed: 4.2ms preprocess, 115.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.8ms
# Speed: 4.0ms preprocess, 120.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.5ms
# Speed: 3.9ms preprocess, 123.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.0ms
# Speed: 6.3ms preprocess, 131.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.2ms
# Speed: 4.3ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.9ms
# Speed: 3.9ms preprocess, 114.9ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.8ms
# Speed: 3.7ms preprocess, 110.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.4ms
# Speed: 7.7ms preprocess, 118.4ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 138.8ms
# Speed: 4.1ms preprocess, 138.8ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 174.5ms
# Speed: 5.2ms preprocess, 174.5ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 187.9ms
# Speed: 6.7ms preprocess, 187.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 158.8ms
# Speed: 3.0ms preprocess, 158.8ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 158.8ms
# Speed: 3.7ms preprocess, 158.8ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 174.1ms
# Speed: 4.2ms preprocess, 174.1ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 168.8ms
# Speed: 4.2ms preprocess, 168.8ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 172.0ms
# Speed: 3.4ms preprocess, 172.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 174.0ms
# Speed: 4.7ms preprocess, 174.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 181.5ms
# Speed: 3.9ms preprocess, 181.5ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 169.5ms
# Speed: 4.6ms preprocess, 169.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 196.9ms
# Speed: 6.8ms preprocess, 196.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 173.9ms
# Speed: 4.1ms preprocess, 173.9ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.3ms
# Speed: 6.7ms preprocess, 183.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 171.4ms
# Speed: 5.1ms preprocess, 171.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 166.2ms
# Speed: 3.9ms preprocess, 166.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 166.8ms
# Speed: 4.6ms preprocess, 166.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 188.5ms
# Speed: 3.9ms preprocess, 188.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 177.0ms
# Speed: 5.1ms preprocess, 177.0ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 173.4ms
# Speed: 3.7ms preprocess, 173.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 181.3ms
# Speed: 6.1ms preprocess, 181.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 173.0ms
# Speed: 5.8ms preprocess, 173.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 157.3ms
# Speed: 6.3ms preprocess, 157.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.9ms
# Speed: 4.1ms preprocess, 119.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 130.1ms
# Speed: 3.8ms preprocess, 130.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.1ms
# Speed: 3.4ms preprocess, 115.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.9ms
# Speed: 3.9ms preprocess, 112.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.3ms
# Speed: 3.9ms preprocess, 125.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.0ms
# Speed: 3.3ms preprocess, 126.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.4ms
# Speed: 5.5ms preprocess, 129.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.0ms
# Speed: 3.6ms preprocess, 129.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 134.5ms
# Speed: 3.6ms preprocess, 134.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.2ms
# Speed: 4.1ms preprocess, 129.2ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.6ms
# Speed: 4.2ms preprocess, 125.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.3ms
# Speed: 3.8ms preprocess, 120.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.6ms
# Speed: 4.3ms preprocess, 117.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.6ms
# Speed: 3.8ms preprocess, 118.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.2ms
# Speed: 3.6ms preprocess, 121.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 136.0ms
# Speed: 3.8ms preprocess, 136.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.9ms
# Speed: 4.1ms preprocess, 120.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.4ms
# Speed: 3.5ms preprocess, 125.4ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.6ms
# Speed: 4.0ms preprocess, 116.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.5ms
# Speed: 5.2ms preprocess, 123.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.8ms
# Speed: 3.5ms preprocess, 111.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.5ms
# Speed: 4.5ms preprocess, 110.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.7ms
# Speed: 4.5ms preprocess, 113.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.9ms
# Speed: 3.6ms preprocess, 124.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.0ms
# Speed: 4.8ms preprocess, 121.0ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.9ms
# Speed: 4.2ms preprocess, 125.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 108.1ms
# Speed: 3.4ms preprocess, 108.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.9ms
# Speed: 4.0ms preprocess, 131.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.3ms
# Speed: 4.0ms preprocess, 124.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.1ms
# Speed: 3.6ms preprocess, 117.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 138.1ms
# Speed: 4.2ms preprocess, 138.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.8ms
# Speed: 5.2ms preprocess, 121.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.9ms
# Speed: 3.5ms preprocess, 131.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 123.4ms
# Speed: 5.4ms preprocess, 123.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.0ms
# Speed: 4.2ms preprocess, 119.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.6ms
# Speed: 3.7ms preprocess, 116.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.4ms
# Speed: 3.9ms preprocess, 113.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.2ms
# Speed: 3.9ms preprocess, 126.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.0ms
# Speed: 4.0ms preprocess, 117.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.0ms
# Speed: 4.0ms preprocess, 116.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.4ms
# Speed: 3.9ms preprocess, 119.4ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.9ms
# Speed: 4.4ms preprocess, 112.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.9ms
# Speed: 6.6ms preprocess, 125.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.5ms
# Speed: 4.9ms preprocess, 116.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.1ms
# Speed: 3.8ms preprocess, 111.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.5ms
# Speed: 6.7ms preprocess, 131.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.9ms
# Speed: 4.5ms preprocess, 117.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.2ms
# Speed: 3.6ms preprocess, 126.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 127.2ms
# Speed: 5.2ms preprocess, 127.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.0ms
# Speed: 6.8ms preprocess, 124.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.4ms
# Speed: 4.1ms preprocess, 118.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.3ms
# Speed: 4.0ms preprocess, 117.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 149.0ms
# Speed: 4.0ms preprocess, 149.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.5ms
# Speed: 3.9ms preprocess, 121.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 142.0ms
# Speed: 4.3ms preprocess, 142.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 141.1ms
# Speed: 4.7ms preprocess, 141.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.6ms
# Speed: 5.0ms preprocess, 124.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 126.3ms
# Speed: 5.0ms preprocess, 126.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.0ms
# Speed: 4.3ms preprocess, 124.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.0ms
# Speed: 4.5ms preprocess, 131.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 142.0ms
# Speed: 4.6ms preprocess, 142.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 143.1ms
# Speed: 7.9ms preprocess, 143.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.6ms
# Speed: 4.5ms preprocess, 131.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 134.0ms
# Speed: 5.0ms preprocess, 134.0ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 161.1ms
# Speed: 4.8ms preprocess, 161.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 145.3ms
# Speed: 3.7ms preprocess, 145.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 163.0ms
# Speed: 6.8ms preprocess, 163.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 199.3ms
# Speed: 4.2ms preprocess, 199.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 210.8ms
# Speed: 3.5ms preprocess, 210.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 241.8ms
# Speed: 4.5ms preprocess, 241.8ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 225.2ms
# Speed: 4.3ms preprocess, 225.2ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 224.7ms
# Speed: 4.0ms preprocess, 224.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 183.8ms
# Speed: 4.3ms preprocess, 183.8ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 191.6ms
# Speed: 5.6ms preprocess, 191.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 175.1ms
# Speed: 4.0ms preprocess, 175.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 236.3ms
# Speed: 8.1ms preprocess, 236.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 205.1ms
# Speed: 4.3ms preprocess, 205.1ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 184.7ms
# Speed: 3.5ms preprocess, 184.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 216.2ms
# Speed: 4.5ms preprocess, 216.2ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 185.0ms
# Speed: 5.1ms preprocess, 185.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 198.0ms
# Speed: 6.9ms preprocess, 198.0ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 166.1ms
# Speed: 5.2ms preprocess, 166.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 175.8ms
# Speed: 6.7ms preprocess, 175.8ms inference, 6.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 188.3ms
# Speed: 4.2ms preprocess, 188.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 228.2ms
# Speed: 4.0ms preprocess, 228.2ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 223.0ms
# Speed: 5.0ms preprocess, 223.0ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 182.0ms
# Speed: 3.4ms preprocess, 182.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 200.1ms
# Speed: 6.9ms preprocess, 200.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 124.3ms
# Speed: 4.9ms preprocess, 124.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.4ms
# Speed: 4.5ms preprocess, 116.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.5ms
# Speed: 4.0ms preprocess, 129.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 155.8ms
# Speed: 5.8ms preprocess, 155.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.4ms
# Speed: 3.5ms preprocess, 125.4ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 135.9ms
# Speed: 5.9ms preprocess, 135.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.2ms
# Speed: 3.8ms preprocess, 119.2ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 140.2ms
# Speed: 3.6ms preprocess, 140.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 158.6ms
# Speed: 4.9ms preprocess, 158.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 155.3ms
# Speed: 3.9ms preprocess, 155.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.5ms
# Speed: 3.4ms preprocess, 121.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.9ms
# Speed: 4.0ms preprocess, 131.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 137.7ms
# ...
#
# 0: 288x640 2 trains, 108.5ms
# Speed: 3.6ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 104.7ms
# Speed: 4.0ms preprocess, 104.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 106.2ms
# Speed: 5.0ms preprocess, 106.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 108.0ms
# Speed: 3.9ms preprocess, 108.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.8ms
# Speed: 4.0ms preprocess, 111.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.6ms
# Speed: 3.9ms preprocess, 116.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 107.8ms
# Speed: 3.7ms preprocess, 107.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 125.2ms
# Speed: 4.1ms preprocess, 125.2ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 109.1ms
# Speed: 3.9ms preprocess, 109.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 103.2ms
# Speed: 3.3ms preprocess, 103.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.5ms
# Speed: 4.1ms preprocess, 114.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.4ms
# Speed: 4.5ms preprocess, 117.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.8ms
# Speed: 5.1ms preprocess, 110.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 120.4ms
# Speed: 4.2ms preprocess, 120.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.0ms
# Speed: 4.0ms preprocess, 112.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.8ms
# Speed: 3.6ms preprocess, 118.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.3ms
# Speed: 4.7ms preprocess, 114.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 114.7ms
# Speed: 4.0ms preprocess, 114.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 107.2ms
# Speed: 3.5ms preprocess, 107.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 118.5ms
# Speed: 4.9ms preprocess, 118.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 116.5ms
# Speed: 3.9ms preprocess, 116.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 112.9ms
# Speed: 3.5ms preprocess, 112.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 121.8ms
# Speed: 3.9ms preprocess, 121.8ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 119.6ms
# Speed: 3.9ms preprocess, 119.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 107.9ms
# Speed: 3.4ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 107.2ms
# Speed: 4.2ms preprocess, 107.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.1ms
# Speed: 5.0ms preprocess, 113.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.4ms
# Speed: 3.3ms preprocess, 111.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 139.0ms
# Speed: 3.9ms preprocess, 139.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 166.5ms
# Speed: 5.9ms preprocess, 166.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 164.5ms
# Speed: 3.5ms preprocess, 164.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 159.9ms
# Speed: 3.9ms preprocess, 159.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 163.3ms
# Speed: 4.8ms preprocess, 163.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 160.8ms
# Speed: 3.4ms preprocess, 160.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 157.9ms
# Speed: 4.7ms preprocess, 157.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 168.4ms
# Speed: 4.0ms preprocess, 168.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 173.1ms
# Speed: 4.5ms preprocess, 173.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 167.3ms
# Speed: 5.7ms preprocess, 167.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 165.9ms
# Speed: 3.8ms preprocess, 165.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 154.8ms
# Speed: 4.9ms preprocess, 154.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 164.4ms
# Speed: 4.7ms preprocess, 164.4ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 163.5ms
# Speed: 3.8ms preprocess, 163.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 164.7ms
# Speed: 3.5ms preprocess, 164.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 156.7ms
# Speed: 4.2ms preprocess, 156.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 164.3ms
# Speed: 4.5ms preprocess, 164.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 165.4ms
# Speed: 3.8ms preprocess, 165.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 169.8ms
# Speed: 5.9ms preprocess, 169.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 198.7ms
# Speed: 3.8ms preprocess, 198.7ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 167.3ms
# Speed: 3.4ms preprocess, 167.3ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 178.5ms
# Speed: 4.2ms preprocess, 178.5ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 145.8ms
# Speed: 4.1ms preprocess, 145.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 129.2ms
# Speed: 3.4ms preprocess, 129.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.8ms
# Speed: 3.9ms preprocess, 111.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 131.7ms
# Speed: 4.1ms preprocess, 131.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 104.0ms
# Speed: 6.0ms preprocess, 104.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 117.3ms
# Speed: 4.2ms preprocess, 117.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 113.0ms
# Speed: 4.0ms preprocess, 113.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 106.3ms
# Speed: 3.8ms preprocess, 106.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 112.6ms
# Speed: 3.9ms preprocess, 112.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 113.7ms
# Speed: 3.8ms preprocess, 113.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 105.7ms
# Speed: 3.6ms preprocess, 105.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 124.9ms
# Speed: 4.2ms preprocess, 124.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 3 trains, 112.3ms
# Speed: 3.9ms preprocess, 112.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 109.4ms
# Speed: 3.6ms preprocess, 109.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 110.6ms
# Speed: 2.7ms preprocess, 110.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.4ms
# Speed: 3.9ms preprocess, 111.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 109.0ms
# Speed: 3.3ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 107.8ms
# Speed: 3.8ms preprocess, 107.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.8ms
# Speed: 3.9ms preprocess, 111.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 122.8ms
# Speed: 4.0ms preprocess, 122.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 118.8ms
# Speed: 5.2ms preprocess, 118.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 112.0ms
# Speed: 4.4ms preprocess, 112.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 106.3ms
# Speed: 3.4ms preprocess, 106.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 112.7ms
# Speed: 3.8ms preprocess, 112.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.1ms
# Speed: 4.0ms preprocess, 111.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 105.8ms
# Speed: 3.5ms preprocess, 105.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 107.6ms
# Speed: 3.8ms preprocess, 107.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 126.4ms
# Speed: 4.7ms preprocess, 126.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 105.6ms
# Speed: 3.5ms preprocess, 105.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 120.4ms
# Speed: 4.1ms preprocess, 120.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 119.6ms
# Speed: 3.9ms preprocess, 119.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 107.6ms
# Speed: 3.5ms preprocess, 107.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 110.6ms
# Speed: 3.9ms preprocess, 110.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 108.6ms
# Speed: 4.1ms preprocess, 108.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 110.4ms
# Speed: 3.7ms preprocess, 110.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 132.7ms
# Speed: 4.5ms preprocess, 132.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 122.5ms
# Speed: 5.4ms preprocess, 122.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 106.2ms
# Speed: 3.3ms preprocess, 106.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 114.1ms
# Speed: 4.0ms preprocess, 114.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 109.2ms
# Speed: 3.9ms preprocess, 109.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 108.7ms
# Speed: 3.5ms preprocess, 108.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 111.4ms
# Speed: 3.9ms preprocess, 111.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 135.5ms
# Speed: 3.9ms preprocess, 135.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 108.4ms
# Speed: 3.8ms preprocess, 108.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 2 trains, 115.7ms
# Speed: 4.8ms preprocess, 115.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.8ms
# Speed: 3.9ms preprocess, 111.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 113.5ms
# Speed: 3.5ms preprocess, 113.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 117.7ms
# Speed: 4.2ms preprocess, 117.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 107.8ms
# Speed: 5.8ms preprocess, 107.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 105.3ms
# Speed: 3.4ms preprocess, 105.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 130.3ms
# Speed: 5.9ms preprocess, 130.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 116.4ms
# Speed: 3.7ms preprocess, 116.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 125.2ms
# Speed: 4.8ms preprocess, 125.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 106.6ms
# Speed: 4.4ms preprocess, 106.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.7ms
# Speed: 4.0ms preprocess, 111.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 105.9ms
# Speed: 3.6ms preprocess, 105.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 113.6ms
# Speed: 4.0ms preprocess, 113.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.2ms
# Speed: 3.9ms preprocess, 111.2ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 121.2ms
# Speed: 3.5ms preprocess, 121.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 114.2ms
# Speed: 4.2ms preprocess, 114.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 115.1ms
# Speed: 5.9ms preprocess, 115.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 107.1ms
# Speed: 3.5ms preprocess, 107.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 109.2ms
# Speed: 4.0ms preprocess, 109.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 115.2ms
# Speed: 3.9ms preprocess, 115.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 111.0ms
# Speed: 3.9ms preprocess, 111.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 148.2ms
# Speed: 4.5ms preprocess, 148.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 114.8ms
# Speed: 3.8ms preprocess, 114.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 107.9ms
# Speed: 3.4ms preprocess, 107.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 1 train, 109.2ms
# Speed: 4.1ms preprocess, 109.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 115.1ms
# Speed: 3.7ms preprocess, 115.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 1 train, 105.3ms
# Speed: 3.4ms preprocess, 105.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 115.8ms
# Speed: 4.3ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 person, 1 train, 116.7ms
# Speed: 5.4ms preprocess, 116.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 train, 120.7ms
# Speed: 3.6ms preprocess, 120.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
# Processed and annotated 126 frames for coach 27 using YOLOv8. Annotated images saved to Processed_Video/DHN_wagon_27/annotated_frames.

# %%
import base64

html_path = os.path.join(OUTPUT_ROOT, "DHN_report.html")

with open(html_path, "w") as f:
    f.write("<html><head><title>Door Detection Report</title></head><body>")
    f.write("<h1>Door Detection Report</h1>")
    f.write("<p>If the door open labels are appearing incorrectly, you can try adjusting the `EDGE_OPEN_THRESHOLD` value in Cell 2 and re-run cells 6 and 7.</p>")
    f.write("<p>Note: This report embeds images directly, which increases file size but allows offline viewing.</p>") # Added note about embedding
    f.write("<table border='1' cellspacing='0' cellpadding='5'>")
    f.write("<tr><th>Segment</th><th>Frame</th><th>Detected Objects</th><th>Image</th></tr>")

    for seg_idx, (s,e,folder,video_file) in enumerate(valid_segments, start=1):
        annotated_frames_dir = os.path.join(folder, "annotated_frames") # Directory where annotated frames are saved
        annotated_jpg_files = sorted(glob.glob(os.path.join(annotated_frames_dir, f"{TRAIN_PREFIX}_{seg_idx}_*_ann.jpg"))) # Look for annotated images


        segment_detection_results = detected_boxes_per_segment.get(seg_idx, [])


        for frame_idx, annotated_img_path in enumerate(annotated_jpg_files):

            if frame_idx < len(segment_detection_results):
                original_img_path, boxes = segment_detection_results[frame_idx]
                detected = ", ".join([f"{label} ({conf:.2f})" for (x,y,w,h,label, conf) in boxes]) if boxes else "None" # Include confidence
            else:
                detected = "Detection results not available"



            with open(annotated_img_path, "rb") as img_file:
                img_data = base64.b64encode(img_file.read()).decode('utf-8')
            img_src = f"data:image/jpeg;base64,{img_data}" # Assuming images are JPEGs

            f.write("<tr>")
            f.write(f"<td>{seg_idx}</td>")
            f.write(f"<td>{frame_idx + 1}</td>")
            f.write(f"<td>{detected}</td>") # Display detected objects with confidence
            f.write(f"<td><img src='{img_src}' width='320'></td>") # Use Data URI for annotated image
            f.write("</tr>")

    f.write("</table></body></html>")

print(f"✅ HTML report saved to {html_path}")
# Out:
# ✅ HTML report saved to Processed_Video/DHN_report.html

# %%
zip_base = "DHN_processed_videos"
shutil.make_archive(zip_base, 'zip', OUTPUT_ROOT)
zip_path = zip_base + ".zip"
print("Zipped output at:", zip_path)
print("Files created under:", OUTPUT_ROOT)
print("Coach folders:", sorted([d for d in os.listdir(OUTPUT_ROOT) if d.startswith(TRAIN_PREFIX)][:50]))
# Out:
# Zipped output at: DHN_processed_videos.zip
# Files created under: Processed_Video
# Coach folders: ['DHN_wagon_1', 'DHN_wagon_10', 'DHN_wagon_11', 'DHN_wagon_12', 'DHN_wagon_13', 'DHN_wagon_14', 'DHN_wagon_15', 'DHN_wagon_16', 'DHN_wagon_17', 'DHN_wagon_18', 'DHN_wagon_19', 'DHN_wagon_2', 'DHN_wagon_20', 'DHN_wagon_21', 'DHN_wagon_22', 'DHN_wagon_23', 'DHN_wagon_24', 'DHN_wagon_25', 'DHN_wagon_26', 'DHN_wagon_27', 'DHN_wagon_3', 'DHN_wagon_4', 'DHN_wagon_5', 'DHN_wagon_6', 'DHN_wagon_7', 'DHN_wagon_8', 'DHN_wagon_9']

# %%
import base64
import shutil

def horizontal_coverage(img):
    """Return start and end columns of non-empty pixels."""
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, th = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    cols = np.where(th.sum(axis=0) > 0)[0]
    if len(cols)==0:
        return None
    return int(cols[0]), int(cols[-1])

report_images = {}

html_path = os.path.join(OUTPUT_ROOT, "DHN_report_minimal.html")
with open(html_path, "w") as f:
    f.write("<html><head><title>Minimal Coverage Door Detection Report</title></head><body>")
    f.write("<h1>Minimal Coverage Door Detection Report</h1>")
    f.write(f"<p>Total coaches detected: {len(valid_segments)}</p>")

    for seg_idx, (s,e,folder,video_file) in enumerate(valid_segments, start=1):
        annotated_frames_dir = os.path.join(folder, "annotated_frames")
        annotated_jpg_files = sorted(glob.glob(os.path.join(annotated_frames_dir, f"{TRAIN_PREFIX}_{seg_idx}_*_ann.jpg")))

        # Compute coverage intervals
        intervals = []
        width = None
        for p in annotated_jpg_files:
            img = cv2.imread(p)
            if width is None:
                width = img.shape[1]
            cov = horizontal_coverage(img)
            if cov is None: continue
            intervals.append((p,cov[0],cov[1]))

        uncovered = set(range(width)) if width else set()
        selected = []

        while uncovered and intervals:
            best = None
            best_new = 0
            for p,x0,x1 in intervals:
                new_cover = len([c for c in list(uncovered) if x0 <= c <= x1])
                if new_cover > best_new:
                    best_new = new_cover
                    best = (p,x0,x1)
            if best is None or best_new==0:
                break
            selected.append(best[0])
            for c in range(best[1], best[2]+1):
                uncovered.discard(c)
            intervals = [iv for iv in intervals if iv[0] != best[0]]

        if not selected and annotated_jpg_files:
            selected = [annotated_jpg_files[0]]

        report_images[seg_idx] = selected


        f.write(f"<h2>Coach {seg_idx}</h2>")
        f.write(f"<p>Clip: {os.path.basename(video_file)} | Duration: {e-s:.2f}s | Selected frames: {len(selected)}</p>")
        f.write("<div style='display:flex; flex-wrap: wrap;'>")
        for imgp in selected:

            with open(imgp, "rb") as img_file:
                img_data = base64.b64encode(img_file.read()).decode('utf-8')
            img_src = f"data:image/jpeg;base64,{img_data}"
            f.write(f"<div style='margin:8px'><img src='{img_src}' width=320></div>")
        f.write("</div><hr>")

    f.write("</body></html>")

print(f"✅ Minimal coverage HTML report saved to {html_path}")

for seg_idx, (s,e,folder,video_file) in enumerate(valid_segments, start=1):
    shutil.copy(html_path, os.path.join(folder, f"{TRAIN_PREFIX}_{seg_idx}_report.html"))

print("✅ HTML report also copied to each coach folder")
# Out:
# ✅ Minimal coverage HTML report saved to Processed_Video/DHN_report_minimal.html
# ✅ HTML report also copied to each coach folder
